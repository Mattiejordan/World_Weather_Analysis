# %% [markdown]
# ## Deliverable 1

# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Using cached gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (4.3.3)
# Collecting geojson>=2.0.0
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.5)
# Requirement already satisfied: backcall in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pygments in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.6.1)
# Requirement already satisfied: decorator in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (49.2.0.post20200714)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.7)
# Requirement already satisfied: ipython-genutils in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: jupyter-client in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.6)
# Requirement already satisfied: tornado>=4.2 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (19.0.1)
# Requirement already satisfied: jinja2 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: Send2Trash in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: prometheus-client in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.16.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: bleach in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: testpath in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: defusedxml in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: packaging in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py): started
#   Building wheel for gmaps (setup.py): finished with status 'done'
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076101 sha256=5edfa5a7d1d3ffb7eb55c5e0f89d5e35d1038438b6cee86152886ddddd2a7860
#   Stored in directory: c:\users\soutexeng2\appdata\local\pip\cache\wheels\30\bd\87\d0d731ee712c34a4d6bace8b1dbf8c8932e22a1625b4a55be4
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import gmaps
import requests
# Import the API key.
from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

gmaps.configure(api_key=g_key)

#filepath = os.path.join("..", "Resources")

# %%
#3. Create a new set of 2,000 random latitudes and longitudes.

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
# # Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\soutexeng2\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
#4. Get the nearest city using the citipy module.
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

#how to find Nearest??

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
#5. Perform an API call with the OpenWeatherMap.


# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a14dcfb1161f287d20292e089da67d3e

# %%
#6. Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | salalah
# Processing Record 2 of Set 13 | olonets
# Processing Record 3 of Set 13 | santa rosa
# Processing Record 4 of Set 13 | hermanus
# Processing Record 5 of Set 13 | kuytun
# Processing Record 6 of Set 13 | buala
# Processing Record 7 of Set 13 | itoman
# Processing Record 8 of Set 13 | miri
# Processing Record 9 of Set 13 | vestmannaeyjar
# Processing Record 10 of Set 13 | vanimo
# Processing Record 11 of Set 13 | barguzin
# Processing Record 12 of Set 13 | rikitea
# Processing Record 13 of Set 13 | vaini
# Processing Record 14 of Set 13 | farafangana
# Processing Record 15 of Set 13 | doha
# Processing Record 16 of Set 13 | arman
# Processing Record 17 of Set 13 | port hardy
# Processing Record 18 of Set 13 | albany
# Processing Record 19 of Set 13 | lebu
# Processing Record 20 of Set 13 | hobart
# Processing Record 21 of Set 13 | saint-philippe
# Processing Record 22 of Set 13 | kodiak
# Processing Record 23 of Set 13 | ushuaia
# Processing Record 24 of Set 13 | kropotkin
# Processing Record 25 of Set 13 | ribeira grande
# Processing Record 26 of Set 13 | sao joao da barra
# Processing Record 27 of Set 13 | athabasca
# Processing Record 28 of Set 13 | punta arenas
# Processing Record 29 of Set 13 | sembakung
# Processing Record 30 of Set 13 | burica
# City not found. Skipping...
# Processing Record 31 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 13 | port alfred
# Processing Record 33 of Set 13 | hervey bay
# Processing Record 34 of Set 13 | hilo
# Processing Record 35 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 13 | mount isa
# Processing Record 37 of Set 13 | lubango
# Processing Record 38 of Set 13 | busselton
# Processing Record 39 of Set 13 | chuy
# Processing Record 40 of Set 13 | faya
# Processing Record 41 of Set 13 | key largo
# Processing Record 42 of Set 13 | kapaa
# Processing Record 43 of Set 13 | torres
# Processing Record 44 of Set 13 | atuona
# Processing Record 45 of Set 13 | mataura
# Processing Record 46 of Set 13 | cabo san lucas
# Processing Record 47 of Set 13 | natal
# Processing Record 48 of Set 13 | georgetown
# Processing Record 49 of Set 13 | mahon
# Processing Record 50 of Set 13 | porto novo
# Processing Record 1 of Set 14 | east london
# Processing Record 2 of Set 14 | southbridge
# Processing Record 3 of Set 14 | amparai
# City not found. Skipping...
# Processing Record 4 of Set 14 | arraial do cabo
# Processing Record 5 of Set 14 | novyy urgal
# Processing Record 6 of Set 14 | barrow
# Processing Record 7 of Set 14 | chalus
# Processing Record 8 of Set 14 | narsaq
# Processing Record 9 of Set 14 | port elizabeth
# Processing Record 10 of Set 14 | kattivakkam
# Processing Record 11 of Set 14 | san francisco
# Processing Record 12 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 14 | butaritari
# Processing Record 14 of Set 14 | bredasdorp
# Processing Record 15 of Set 14 | dunedin
# Processing Record 16 of Set 14 | bengkulu
# Processing Record 17 of Set 14 | goure
# Processing Record 18 of Set 14 | bonthe
# Processing Record 19 of Set 14 | mabaruma
# Processing Record 20 of Set 14 | bluff
# Processing Record 21 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 14 | walvis bay
# Processing Record 23 of Set 14 | coquimbo
# Processing Record 24 of Set 14 | xinyu
# Processing Record 25 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | arlit
# Processing Record 27 of Set 14 | ust-nera
# Processing Record 28 of Set 14 | baherden
# Processing Record 29 of Set 14 | avarua
# Processing Record 30 of Set 14 | mar del plata
# Processing Record 31 of Set 14 | kaitangata
# Processing Record 32 of Set 14 | kruisfontein
# Processing Record 33 of Set 14 | puerto ayora
# Processing Record 34 of Set 14 | souillac
# Processing Record 35 of Set 14 | cherskiy
# Processing Record 36 of Set 14 | los llanos de aridane
# Processing Record 37 of Set 14 | san patricio
# Processing Record 38 of Set 14 | norman wells
# Processing Record 39 of Set 14 | kavieng
# Processing Record 40 of Set 14 | ambilobe
# Processing Record 41 of Set 14 | santa elena
# Processing Record 42 of Set 14 | pangnirtung
# Processing Record 43 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 14 | nakhon thai
# Processing Record 45 of Set 14 | tuktoyaktuk
# Processing Record 46 of Set 14 | tasiilaq
# Processing Record 47 of Set 14 | medea
# Processing Record 48 of Set 14 | huarmey
# Processing Record 49 of Set 14 | cape town
# Processing Record 50 of Set 14 | new norfolk
# Processing Record 1 of Set 15 | nhulunbuy
# Processing Record 2 of Set 15 | qaanaaq
# Processing Record 3 of Set 15 | centerville
# Processing Record 4 of Set 15 | kem
# Processing Record 5 of Set 15 | khatanga
# Processing Record 6 of Set 15 | klaksvik
# Processing Record 7 of Set 15 | kieta
# Processing Record 8 of Set 15 | raahe
# Processing Record 9 of Set 15 | mount pleasant
# Processing Record 10 of Set 15 | longyearbyen
# Processing Record 11 of Set 15 | laramie
# Processing Record 12 of Set 15 | torbay
# Processing Record 13 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 15 | guarizama
# Processing Record 15 of Set 15 | haines junction
# Processing Record 16 of Set 15 | tateyama
# Processing Record 17 of Set 15 | jamestown
# Processing Record 18 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 15 | beloha
# Processing Record 20 of Set 15 | itapuranga
# Processing Record 21 of Set 15 | airai
# Processing Record 22 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 15 | codrington
# Processing Record 24 of Set 15 | port blair
# Processing Record 25 of Set 15 | tiksi
# Processing Record 26 of Set 15 | carnarvon
# Processing Record 27 of Set 15 | grand-lahou
# Processing Record 28 of Set 15 | pacific grove
# Processing Record 29 of Set 15 | pantai remis
# Processing Record 30 of Set 15 | saint helens
# Processing Record 31 of Set 15 | ferrol
# Processing Record 32 of Set 15 | srednekolymsk
# Processing Record 33 of Set 15 | okhotsk
# Processing Record 34 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 15 | batemans bay
# Processing Record 36 of Set 15 | hasaki
# Processing Record 37 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 38 of Set 15 | praia da vitoria
# Processing Record 39 of Set 15 | salto
# Processing Record 40 of Set 15 | sept-iles
# Processing Record 41 of Set 15 | goundam
# Processing Record 42 of Set 15 | nanortalik
# Processing Record 43 of Set 15 | gigmoto
# Processing Record 44 of Set 15 | yulara
# Processing Record 45 of Set 15 | faanui
# Processing Record 46 of Set 15 | sao filipe
# Processing Record 47 of Set 15 | marand
# Processing Record 48 of Set 15 | beringovskiy
# Processing Record 49 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 15 | khislavichi
# Processing Record 1 of Set 16 | broome
# Processing Record 2 of Set 16 | zavodoukovsk
# Processing Record 3 of Set 16 | kayes
# Processing Record 4 of Set 16 | tsabong
# Processing Record 5 of Set 16 | obo
# Processing Record 6 of Set 16 | husavik
# Processing Record 7 of Set 16 | yunyang
# Processing Record 8 of Set 16 | benghazi
# Processing Record 9 of Set 16 | nevsehir
# Processing Record 10 of Set 16 | tuatapere
# Processing Record 11 of Set 16 | victoria
# Processing Record 12 of Set 16 | upernavik
# Processing Record 13 of Set 16 | bac lieu
# Processing Record 14 of Set 16 | yar-sale
# Processing Record 15 of Set 16 | chom bung
# City not found. Skipping...
# Processing Record 16 of Set 16 | batagay
# Processing Record 17 of Set 16 | sitka
# Processing Record 18 of Set 16 | buritis
# Processing Record 19 of Set 16 | lincoln
# Processing Record 20 of Set 16 | moravska trebova
# Processing Record 21 of Set 16 | nelson
# Processing Record 22 of Set 16 | mitsamiouli
# Processing Record 23 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 16 | grindavik
# Processing Record 25 of Set 16 | mantua
# Processing Record 26 of Set 16 | muros
# Processing Record 27 of Set 16 | taquarana
# Processing Record 28 of Set 16 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 16 | luoyang
# Processing Record 30 of Set 16 | cidreira
# Processing Record 31 of Set 16 | anadyr
# Processing Record 32 of Set 16 | marau
# Processing Record 33 of Set 16 | mezen
# Processing Record 34 of Set 16 | jalu
# Processing Record 35 of Set 16 | fortuna
# Processing Record 36 of Set 16 | severo-kurilsk
# Processing Record 37 of Set 16 | wucheng
# Processing Record 38 of Set 16 | sal rei
# Processing Record 39 of Set 16 | calamar
# Processing Record 40 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 16 | ahipara
# Processing Record 42 of Set 16 | thompson
# Processing Record 43 of Set 16 | douglas
# Processing Record 44 of Set 16 | ulagan
# Processing Record 45 of Set 16 | karratha
# Processing Record 46 of Set 16 | itarema
# Processing Record 47 of Set 16 | kaabong
# Processing Record 48 of Set 16 | esperance
# Processing Record 49 of Set 16 | lagos
# Processing Record 50 of Set 16 | viedma
# Processing Record 1 of Set 17 | tecpan
# Processing Record 2 of Set 17 | napasar
# Processing Record 3 of Set 17 | lianzhou
# Processing Record 4 of Set 17 | adrar
# Processing Record 5 of Set 17 | calapi
# Processing Record 6 of Set 17 | khani
# Processing Record 7 of Set 17 | marawi
# Processing Record 8 of Set 17 | brae
# Processing Record 9 of Set 17 | helong
# Processing Record 10 of Set 17 | alofi
# Processing Record 11 of Set 17 | eureka
# Processing Record 12 of Set 17 | maceio
# Processing Record 13 of Set 17 | nyurba
# Processing Record 14 of Set 17 | shitanjing
# Processing Record 15 of Set 17 | lorengau
# Processing Record 16 of Set 17 | ponta do sol
# Processing Record 17 of Set 17 | poum
# Processing Record 18 of Set 17 | sisimiut
# Processing Record 19 of Set 17 | vardo
# Processing Record 20 of Set 17 | leningradskiy
# Processing Record 21 of Set 17 | ilo
# Processing Record 22 of Set 17 | port hedland
# Processing Record 23 of Set 17 | dawson creek
# Processing Record 24 of Set 17 | port arthur
# Processing Record 25 of Set 17 | kishtwar
# Processing Record 26 of Set 17 | yellowknife
# Processing Record 27 of Set 17 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 17 | raudeberg
# Processing Record 29 of Set 17 | port-gentil
# Processing Record 30 of Set 17 | makakilo city
# Processing Record 31 of Set 17 | constitucion
# Processing Record 32 of Set 17 | nome
# Processing Record 33 of Set 17 | sola
# Processing Record 34 of Set 17 | kirensk
# Processing Record 35 of Set 17 | zhigansk
# Processing Record 36 of Set 17 | saint george
# Processing Record 37 of Set 17 | punta cardon
# Processing Record 38 of Set 17 | kalmunai
# Processing Record 39 of Set 17 | oktyabrskoye
# Processing Record 40 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 17 | qasigiannguit
# Processing Record 42 of Set 17 | saint-augustin
# Processing Record 43 of Set 17 | olafsvik
# Processing Record 44 of Set 17 | lisakovsk
# Processing Record 45 of Set 17 | saint-francois
# Processing Record 46 of Set 17 | kushima
# Processing Record 47 of Set 17 | grand-santi
# Processing Record 48 of Set 17 | vila franca do campo
# Processing Record 49 of Set 17 | deputatskiy
# Processing Record 50 of Set 17 | jining
# Processing Record 1 of Set 18 | saskylakh
# Processing Record 2 of Set 18 | mana
# Processing Record 3 of Set 18 | necochea
# Processing Record 4 of Set 18 | celestun
# Processing Record 5 of Set 18 | tual
# Processing Record 6 of Set 18 | balsas
# Processing Record 7 of Set 18 | singleton
# Processing Record 8 of Set 18 | nikolskoye
# Processing Record 9 of Set 18 | geraldton
# Processing Record 10 of Set 18 | evreux
# Processing Record 11 of Set 18 | rylsk
# Processing Record 12 of Set 18 | inhambane
# Processing Record 13 of Set 18 | ostrovnoy
# Processing Record 14 of Set 18 | leh
# Processing Record 15 of Set 18 | juneau
# Processing Record 16 of Set 18 | alice springs
# Processing Record 17 of Set 18 | hofn
# Processing Record 18 of Set 18 | talara
# Processing Record 19 of Set 18 | tura
# Processing Record 20 of Set 18 | union
# Processing Record 21 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 18 | meulaboh
# Processing Record 23 of Set 18 | callaguip
# Processing Record 24 of Set 18 | polikhronon
# Processing Record 25 of Set 18 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 18 | kolondieba
# Processing Record 27 of Set 18 | parsabad
# Processing Record 28 of Set 18 | ontario
# Processing Record 29 of Set 18 | praia
# Processing Record 30 of Set 18 | oranjestad
# Processing Record 31 of Set 18 | divnomorskoye
# Processing Record 32 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 18 | maloshuyka
# City not found. Skipping...
# Processing Record 34 of Set 18 | lunglei
# Processing Record 35 of Set 18 | bathsheba
# Processing Record 36 of Set 18 | buta
# Processing Record 37 of Set 18 | isla mujeres
# Processing Record 38 of Set 18 | naze
# Processing Record 39 of Set 18 | garden city
# Processing Record 40 of Set 18 | esfarayen
# Processing Record 41 of Set 18 | san andres
# Processing Record 42 of Set 18 | matara
# Processing Record 43 of Set 18 | yerofey pavlovich
# Processing Record 44 of Set 18 | pilar
# Processing Record 45 of Set 18 | kurchum
# Processing Record 46 of Set 18 | iwanai
# Processing Record 47 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 18 | flinders
# Processing Record 49 of Set 18 | karatau
# Processing Record 50 of Set 18 | umm lajj
# Processing Record 1 of Set 19 | dikson
# Processing Record 2 of Set 19 | camacha
# Processing Record 3 of Set 19 | roald
# Processing Record 4 of Set 19 | north platte
# Processing Record 5 of Set 19 | socorro
# Processing Record 6 of Set 19 | san carlos del zulia
# Processing Record 7 of Set 19 | turinsk
# Processing Record 8 of Set 19 | planaltina
# Processing Record 9 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 19 | bethel
# Processing Record 11 of Set 19 | kirakira
# Processing Record 12 of Set 19 | bournemouth
# Processing Record 13 of Set 19 | turayf
# Processing Record 14 of Set 19 | ha tinh
# Processing Record 15 of Set 19 | mazatlan
# Processing Record 16 of Set 19 | west plains
# Processing Record 17 of Set 19 | alyangula
# Processing Record 18 of Set 19 | libreville
# Processing Record 19 of Set 19 | dogondoutchi
# Processing Record 20 of Set 19 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 19 | maragogi
# Processing Record 22 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 19 | kununurra
# Processing Record 24 of Set 19 | erzin
# Processing Record 25 of Set 19 | henties bay
# Processing Record 26 of Set 19 | coffs harbour
# Processing Record 27 of Set 19 | bahia blanca
# Processing Record 28 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 19 | cockburn town
# Processing Record 30 of Set 19 | suao
# City not found. Skipping...
# Processing Record 31 of Set 19 | camopi
# Processing Record 32 of Set 19 | katsuura
# Processing Record 33 of Set 19 | taormina
# Processing Record 34 of Set 19 | ushirombo
# Processing Record 35 of Set 19 | ust-omchug
# Processing Record 36 of Set 19 | namibe
# Processing Record 37 of Set 19 | voyvozh
# Processing Record 38 of Set 19 | minbu
# Processing Record 39 of Set 19 | havelock
# Processing Record 40 of Set 19 | akyab
# Processing Record 41 of Set 19 | margate
# Processing Record 42 of Set 19 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 19 | cayenne
# Processing Record 44 of Set 19 | port lincoln
# Processing Record 45 of Set 19 | tefe
# Processing Record 46 of Set 19 | cabedelo
# Processing Record 47 of Set 19 | kloulklubed
# Processing Record 48 of Set 19 | parana
# Processing Record 49 of Set 19 | la ronge
# Processing Record 50 of Set 19 | lata
# Processing Record 1 of Set 20 | iracoubo
# Processing Record 2 of Set 20 | ancud
# Processing Record 3 of Set 20 | jucas
# Processing Record 4 of Set 20 | talnakh
# Processing Record 5 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 20 | kribi
# Processing Record 7 of Set 20 | russell
# Processing Record 8 of Set 20 | pisco
# Processing Record 9 of Set 20 | frunze
# Processing Record 10 of Set 20 | fairbanks
# Processing Record 11 of Set 20 | kot samaba
# Processing Record 12 of Set 20 | sabha
# Processing Record 13 of Set 20 | sao bernardo
# Processing Record 14 of Set 20 | north bend
# Processing Record 15 of Set 20 | aksu
# Processing Record 16 of Set 20 | saldanha
# Processing Record 17 of Set 20 | mujiayingzi
# Processing Record 18 of Set 20 | rio gallegos
# Processing Record 19 of Set 20 | guerrero negro
# Processing Record 20 of Set 20 | chumikan
# Processing Record 21 of Set 20 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 20 | sami
# Processing Record 23 of Set 20 | morgan city
# Processing Record 24 of Set 20 | zyryanka
# Processing Record 25 of Set 20 | nalut
# Processing Record 26 of Set 20 | boyolangu
# Processing Record 27 of Set 20 | arrecife
# Processing Record 28 of Set 20 | saint-pierre
# Processing Record 29 of Set 20 | rovaniemi
# Processing Record 30 of Set 20 | iqaluit
# Processing Record 31 of Set 20 | rio grande
# Processing Record 32 of Set 20 | tuy hoa
# Processing Record 33 of Set 20 | kavaratti
# Processing Record 34 of Set 20 | hithadhoo
# Processing Record 35 of Set 20 | kolokani
# Processing Record 36 of Set 20 | sakaiminato
# Processing Record 37 of Set 20 | kathmandu
# Processing Record 38 of Set 20 | ust-kuyga
# Processing Record 39 of Set 20 | bambanglipuro
# Processing Record 40 of Set 20 | hanyang
# Processing Record 41 of Set 20 | palmer
# Processing Record 42 of Set 20 | sakakah
# Processing Record 43 of Set 20 | lompoc
# Processing Record 44 of Set 20 | kazerun
# Processing Record 45 of Set 20 | christchurch
# Processing Record 46 of Set 20 | coihueco
# Processing Record 47 of Set 20 | lumberton
# Processing Record 48 of Set 20 | fergus falls
# Processing Record 49 of Set 20 | bullhead city
# Processing Record 50 of Set 20 | lakewood
# Processing Record 1 of Set 21 | akonolinga
# Processing Record 2 of Set 21 | pevek
# Processing Record 3 of Set 21 | riyadh
# Processing Record 4 of Set 21 | atambua
# Processing Record 5 of Set 21 | sorland
# Processing Record 6 of Set 21 | mount gambier
# Processing Record 7 of Set 21 | nivala
# Processing Record 8 of Set 21 | kostomuksha
# Processing Record 9 of Set 21 | kenai
# Processing Record 10 of Set 21 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 21 | sturgeon bay
# Processing Record 12 of Set 21 | fenoarivo
# Processing Record 13 of Set 21 | prabumulih
# Processing Record 14 of Set 21 | auki
# Processing Record 15 of Set 21 | ixtapa
# Processing Record 16 of Set 21 | benjamin constant
# Processing Record 17 of Set 21 | ponta delgada
# Processing Record 18 of Set 21 | komsomolskiy
# Processing Record 19 of Set 21 | havre-saint-pierre
# Processing Record 20 of Set 21 | vao
# Processing Record 21 of Set 21 | bay roberts
# Processing Record 22 of Set 21 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 21 | xuddur
# Processing Record 24 of Set 21 | huanuco
# Processing Record 25 of Set 21 | ketchikan
# Processing Record 26 of Set 21 | ballina
# Processing Record 27 of Set 21 | batagay-alyta
# Processing Record 28 of Set 21 | tautira
# Processing Record 29 of Set 21 | quatre cocos
# Processing Record 30 of Set 21 | santa maria
# Processing Record 31 of Set 21 | upata
# Processing Record 32 of Set 21 | laguna
# Processing Record 33 of Set 21 | huilong
# Processing Record 34 of Set 21 | chokurdakh
# Processing Record 35 of Set 21 | kijang
# Processing Record 36 of Set 21 | sao paulo de olivenca
# Processing Record 37 of Set 21 | saint anthony
# Processing Record 38 of Set 21 | naziya
# Processing Record 39 of Set 21 | bayir
# Processing Record 40 of Set 21 | araouane
# Processing Record 41 of Set 21 | nador
# Processing Record 42 of Set 21 | taoudenni
# Processing Record 43 of Set 21 | takoradi
# Processing Record 44 of Set 21 | bierbeek
# Processing Record 45 of Set 21 | omboue
# Processing Record 46 of Set 21 | moose factory
# Processing Record 47 of Set 21 | staraya kulatka
# Processing Record 48 of Set 21 | kelamangalam
# Processing Record 49 of Set 21 | portree
# Processing Record 50 of Set 21 | galle
# Processing Record 1 of Set 22 | sugar hill
# Processing Record 2 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 22 | lismore
# Processing Record 4 of Set 22 | castro
# Processing Record 5 of Set 22 | corbelia
# Processing Record 6 of Set 22 | oktyabrskiy
# Processing Record 7 of Set 22 | ottawa
# Processing Record 8 of Set 22 | west bay
# Processing Record 9 of Set 22 | kahului
# Processing Record 10 of Set 22 | isangel
# Processing Record 11 of Set 22 | freeport
# Processing Record 12 of Set 22 | khash
# Processing Record 13 of Set 22 | pangkalanbuun
# Processing Record 14 of Set 22 | rincon
# Processing Record 15 of Set 22 | samana
# Processing Record 16 of Set 22 | aswan
# Processing Record 17 of Set 22 | mvuma
# Processing Record 18 of Set 22 | varzea grande
# Processing Record 19 of Set 22 | abu jubayhah
# City not found. Skipping...
# Processing Record 20 of Set 22 | balikpapan
# Processing Record 21 of Set 22 | lavrentiya
# Processing Record 22 of Set 22 | comodoro rivadavia
# Processing Record 23 of Set 22 | preobrazhenka
# Processing Record 24 of Set 22 | hobyo
# Processing Record 25 of Set 22 | sibut
# Processing Record 26 of Set 22 | waitati
# Processing Record 27 of Set 22 | mareeba
# Processing Record 28 of Set 22 | nouadhibou
# Processing Record 29 of Set 22 | antofagasta
# Processing Record 30 of Set 22 | mentok
# City not found. Skipping...
# Processing Record 31 of Set 22 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 22 | nyakahanga
# Processing Record 33 of Set 22 | jieshi
# Processing Record 34 of Set 22 | agbor
# Processing Record 35 of Set 22 | yerbogachen
# Processing Record 36 of Set 22 | marzuq
# Processing Record 37 of Set 22 | dutse
# Processing Record 38 of Set 22 | vilyuysk
# Processing Record 39 of Set 22 | xunchang
# Processing Record 40 of Set 22 | maniitsoq
# Processing Record 41 of Set 22 | bilibino
# Processing Record 42 of Set 22 | san matias
# Processing Record 43 of Set 22 | charlestown
# Processing Record 44 of Set 22 | ilulissat
# Processing Record 45 of Set 22 | sabang
# Processing Record 46 of Set 22 | opuwo
# Processing Record 47 of Set 22 | kutum
# Processing Record 48 of Set 22 | huambo
# Processing Record 49 of Set 22 | trenggalek
# Processing Record 50 of Set 22 | bobonong
# City not found. Skipping...
# Processing Record 1 of Set 23 | amazar
# Processing Record 2 of Set 23 | pipri
# Processing Record 3 of Set 23 | tkvarcheli
# City not found. Skipping...
# Processing Record 4 of Set 23 | tazovskiy
# Processing Record 5 of Set 23 | masallatah
# Processing Record 6 of Set 23 | acarau
# Processing Record 7 of Set 23 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 23 | cruzeiro do sul
# Processing Record 9 of Set 23 | buraydah
# Processing Record 10 of Set 23 | ajdabiya
# Processing Record 11 of Set 23 | nizhniy kuranakh
# Processing Record 12 of Set 23 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 23 | tsumeb
# Processing Record 14 of Set 23 | kars
# Processing Record 15 of Set 23 | beli manastir
# Processing Record 16 of Set 23 | chenghai
# Processing Record 17 of Set 23 | pimentel
# Processing Record 18 of Set 23 | acapulco
# Processing Record 19 of Set 23 | te anau
# Processing Record 20 of Set 23 | port ellen
# City not found. Skipping...
# Processing Record 21 of Set 23 | coihaique
# Processing Record 22 of Set 23 | waingapu
# Processing Record 23 of Set 23 | swellendam
# Processing Record 24 of Set 23 | tutoia
# Processing Record 25 of Set 23 | ilam
# Processing Record 26 of Set 23 | porto velho
# Processing Record 27 of Set 23 | lagoa
# Processing Record 28 of Set 23 | verkhnevilyuysk
# Processing Record 29 of Set 23 | grand gaube
# Processing Record 30 of Set 23 | atar
# Processing Record 31 of Set 23 | preobrazheniye
# Processing Record 32 of Set 23 | dakar
# Processing Record 33 of Set 23 | kidal
# Processing Record 34 of Set 23 | soe
# Processing Record 35 of Set 23 | kamyzyak
# Processing Record 36 of Set 23 | bacolod
# Processing Record 37 of Set 23 | kishi
# Processing Record 38 of Set 23 | kingsland
# Processing Record 39 of Set 23 | pavlovka
# Processing Record 40 of Set 23 | provideniya
# Processing Record 41 of Set 23 | vila velha
# Processing Record 42 of Set 23 | baiyin
# Processing Record 43 of Set 23 | mahebourg
# Processing Record 44 of Set 23 | douentza
# Processing Record 45 of Set 23 | pelotas
# Processing Record 46 of Set 23 | kirkwall
# Processing Record 47 of Set 23 | avera
# Processing Record 48 of Set 23 | dunmore town
# Processing Record 49 of Set 23 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 23 | jefferson city
# Processing Record 1 of Set 24 | muscat
# Processing Record 2 of Set 24 | coahuayana
# Processing Record 3 of Set 24 | red bluff
# Processing Record 4 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 24 | waddan
# Processing Record 6 of Set 24 | oneonta
# Processing Record 7 of Set 24 | bilma
# Processing Record 8 of Set 24 | moshenskoye
# Processing Record 9 of Set 24 | belmonte
# Processing Record 10 of Set 24 | suntar
# Processing Record 11 of Set 24 | altus
# Processing Record 12 of Set 24 | sulangan
# Processing Record 13 of Set 24 | kibre mengist
# Processing Record 14 of Set 24 | agadez
# Processing Record 15 of Set 24 | biltine
# Processing Record 16 of Set 24 | korla
# Processing Record 17 of Set 24 | richards bay
# Processing Record 18 of Set 24 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 24 | baculin
# Processing Record 20 of Set 24 | pomabamba
# Processing Record 21 of Set 24 | clyde river
# Processing Record 22 of Set 24 | labuhan
# Processing Record 23 of Set 24 | guelengdeng
# City not found. Skipping...
# Processing Record 24 of Set 24 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 24 | dongkan
# Processing Record 26 of Set 24 | pahrump
# Processing Record 27 of Set 24 | ellensburg
# Processing Record 28 of Set 24 | aripuana
# Processing Record 29 of Set 24 | knysna
# Processing Record 30 of Set 24 | omsukchan
# Processing Record 31 of Set 24 | jadu
# Processing Record 32 of Set 24 | sur
# Processing Record 33 of Set 24 | namatanai
# Processing Record 34 of Set 24 | half moon bay
# Processing Record 35 of Set 24 | iguape
# Processing Record 36 of Set 24 | san jeronimo
# Processing Record 37 of Set 24 | mildura
# Processing Record 38 of Set 24 | santa isabel do rio negro
# Processing Record 39 of Set 24 | shenjiamen
# Processing Record 40 of Set 24 | luderitz
# Processing Record 41 of Set 24 | conceicao do araguaia
# Processing Record 42 of Set 24 | lima
# Processing Record 43 of Set 24 | caravelas
# Processing Record 44 of Set 24 | bubaque
# Processing Record 45 of Set 24 | podporozhye
# Processing Record 46 of Set 24 | dingle
# Processing Record 47 of Set 24 | semporna
# Processing Record 48 of Set 24 | codajas
# Processing Record 49 of Set 24 | glendive
# Processing Record 50 of Set 24 | snyder
# Processing Record 1 of Set 25 | aden
# Processing Record 2 of Set 25 | orapa
# Processing Record 3 of Set 25 | saint-gilles
# Processing Record 4 of Set 25 | nabire
# Processing Record 5 of Set 25 | borama
# City not found. Skipping...
# Processing Record 6 of Set 25 | hami
# Processing Record 7 of Set 25 | byron bay
# Processing Record 8 of Set 25 | honningsvag
# Processing Record 9 of Set 25 | tilichiki
# Processing Record 10 of Set 25 | ambon
# Processing Record 11 of Set 25 | port macquarie
# Processing Record 12 of Set 25 | nantucket
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#7 Add the data to a new DataFrame.

#like # Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Salalah  17.02   54.09     71.60        78          20        4.70
# 1         Olonets  60.98   32.97     44.73        74          19       13.11
# 2      Santa Rosa  14.31  121.11     84.99        74          75        5.50
# 3        Hermanus -34.42   19.23     55.99        90          89        8.99
# 4          Kuytun  54.34  101.50     14.59        96         100        5.59
# 5           Buala  -8.14  159.59     85.69        65          18        3.04
# 6          Itoman  26.12  127.67     82.40        78          20        5.82
# 7            Miri   4.41  114.01     82.40        83          20        4.70
# 8  Vestmannaeyjar  63.44  -20.27     40.75        69          99       16.44
# 9          Vanimo  -2.67  141.30     86.49        60          72        6.22
#
#   Country                 Date
# 0      OM  2020-11-07 01:09:30
# 1      RU  2020-11-07 01:09:30
# 2      PH  2020-11-07 01:09:31
# 3      ZA  2020-11-07 01:00:23
# 4      RU  2020-11-07 01:09:31
# 5      SB  2020-11-07 01:04:49
# 6      JP  2020-11-07 01:05:49
# 7      MY  2020-11-07 01:09:31
# 8      IS  2020-11-07 01:04:36
# 9      PG  2020-11-07 01:09:32

# %%
#8. Export the DataFrame as a CSV file, 
# and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
#output_data_file = "../WeatherPy_Database.csv"

# I don't see it saved yet
city_data_df.to_csv(output_data_file)
